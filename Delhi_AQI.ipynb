# %% [markdown]
# <a href="https://colab.research.google.com/github/pranatixsharma/Delhi-AQI-source-allocation/blob/main/Delhi_AQI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem Statement
#
# 1. What are the main causes of pollution in various areas in Delhi NCR?
# 2. What measures should be taken in what area to reduce it, and quanitfy how they might help.
# 3. What percentage of this is human activities based and what is just natural weather pattern?

# %% [markdown]
# #Analytical Approach
# 1. Causes -> Classification model to classify each area's profile into one of the main causes based on air elements profile
# 2. Measures to be taken -> Prescriptive decision analysis model
# 3. natural vs man made -> binary classification

# %% [markdown]
# # Data collection
# import dataset

# %%
import pandas as pd
Delhi = pd.read_csv("/content/delhi_ncr_aqi_dataset.csv")
Delhi.head()
# Out:
#               datetime        date  year  month  day  hour day_of_week  \
# 0  2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
# 1  2020-01-01 12:00:00  2020-01-01  2020      1    1    12   Wednesday
# 2  2020-01-01 18:00:00  2020-01-01  2020      1    1    18   Wednesday
# 3  2020-01-01 23:00:00  2020-01-01  2020      1    1    23   Wednesday
# 4  2020-01-01 06:00:00  2020-01-01  2020      1    1     6   Wednesday
#
#    is_weekend  season   city  ...    no2   so2    co    o3  temperature  \
# 0           0  winter  Delhi  ...  119.6  47.7  5.19  12.3          9.4
# 1           0  winter  Delhi  ...  117.9  39.3  4.32  15.8         20.6
# 2           0  winter  Delhi  ...  150.1  36.3  7.13  14.3         12.4
# 3           0  winter  Delhi  ...  142.0  30.3  4.90  13.2         14.4
# 4           0  winter  Delhi  ...  138.4  41.5  7.56  15.4          6.8
#
#    humidity  wind_speed  visibility  aqi  aqi_category
# ...

# %% [markdown]
# #Data understanding/ EDA
